# %%
using FCSFitting

# %%
filepath = raw"fcs_sample.txt"
data = read_fcs(filepath; start_idx = 20, end_idx = 300);

# %%
model = fcs_3d
diffusivity=5e-11
fig, fit, scale = fcs_plot(model, data.channels[1], [2e-7, 1.0, 0.0, 5, 1e-7, 0.1]; lower = [1e-8, 0.9, -1e-5, 1, 1e-8, 0.0], upper = [1e-6, 1.1, 1e-5, 20, 1e-4, 0.5], diffusivity)
fig

# %%
fcs_table(model, fit, scale; diffusivity)
# Out:
# <table>
#   <thead>
#     <tr class = "columnLabelRow">
#       <th style = "font-weight: bold; text-align: left;">Parameters</th>
#       <th style = "font-weight: bold; text-align: right;">Values</th>
#       <th style = "font-weight: bold; text-align: right;">Std. Dev.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr class = "dataRow">
#       <td style = "text-align: left;">Diffusion time τ_D [s]</td>
#       <td style = "text-align: right;">0.0003124</td>
#       <td style = "text-align: right;">0.0002315</td>
#     </tr>
#     <tr class = "dataRow">
#       <td style = "text-align: left;">Beam width w_0 [m]</td>
#       <td style = "text-align: right;">2.5e-07</td>
#       <td style = "text-align: right;">7.411e-11</td>
#     </tr>
#     <tr class = "dataRow">
#       <td style = "text-align: left;">Current amplitude G(0)</td>
#       <td style = "text-align: right;">1</td>
#       <td style = "text-align: right;">5.488e-05</td>
#     </tr>
#     <tr class = "dataRow">
# ...
