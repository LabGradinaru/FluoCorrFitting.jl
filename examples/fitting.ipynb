# %%
using FCSFitting

# %%
using DelimitedFiles

filepath = raw"fcs_sample.txt"
data = read_fcs(filepath; start_idx = 20, end_idx = 300);

# %%
using CairoMakie
using LaTeXStrings

diffusivity=5e-11; offset=0.0
spec = FCSModelSpec(dim = FCSFitting.d3, anom = FCSFitting.none, offset = offset, diffusivity = diffusivity)

initial_parameters = [1.0, 5, 2e-7, 1e-7, 0.1]
lower_bounds = [0.9, 1, 1e-8, 1e-8, 0.0]
upper_bounds = [1.1, 20, 1e-6, 1e-4, 0.5]
fit = fcs_fit(spec, data.channels[3], initial_parameters; lower = lower_bounds, upper = upper_bounds)
fig, _ = fcs_plot(fit, data.channels[3]; fontsize=20)
fig

# %%
using PrettyTables

fcs_table(fit; units=["", "", "n", "μ", ""], gof_metric=aic)
# Out:
# <table>
#   <thead>
#     <tr class = "columnLabelRow">
#       <th style = "font-weight: bold; text-align: left;">Parameters</th>
#       <th style = "font-weight: bold; text-align: right;">Values</th>
#       <th style = "font-weight: bold; text-align: right;">Std. Dev.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr class = "dataRow">
#       <td style = "text-align: left;">Current amplitude</td>
#       <td style = "text-align: right;">1</td>
#       <td style = "text-align: right;">2.828e-7</td>
#     </tr>
#     <tr class = "dataRow">
#       <td style = "text-align: left;">Structure factor</td>
#       <td style = "text-align: right;">7.996</td>
#       <td style = "text-align: right;">0.0109</td>
#     </tr>
#     <tr class = "dataRow">
#       <td style = "text-align: left;">Beam width [nm]</td>
#       <td style = "text-align: right;">250</td>
#       <td style = "text-align: right;">0.007688</td>
#     </tr>
#     <tr class = "dataRow">
# ...

# %%
fig, ρ = resid_acf_plot(fit; maxlag=50)
fig
